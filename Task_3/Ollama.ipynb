# %%
import ollama

client=ollama.Client()

model="tinyllama"
prompt="What is capital of india?"

response=client.generate(model=model,prompt=prompt)

print(response.response)
# Out:
# The capital of India is New Delhi, and its current name is "Delhi". The earlier names for Delhi were Mehrauli (Mohrauli) and Fatehpuri. Delhi was once known as Chandni Chowk, which means the Light House or Light Cone in Sanskrit. The city of New Delhi was established by the Mughal Emperor Shah Jahan after his death.
